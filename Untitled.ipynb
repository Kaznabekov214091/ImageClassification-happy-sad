# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (2.9.1)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Panda\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\tensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Consider using the `--user` option or check the permissions.
# Collecting tensorflow-gpu
#   Using cached tensorflow_gpu-2.10.0-cp310-cp310-win_amd64.whl (455.9 MB)
# Requirement already satisfied: opencv-python in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (4.6.0.66)
# Requirement already satisfied: matplotlib in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (3.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: setuptools in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: packaging in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.47.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
#   Using cached tensorflow_gpu-2.9.2-cp310-cp310-win_amd64.whl (444.2 MB)
# Requirement already satisfied: cycler>=0.10 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.8)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.9.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.1.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\panda\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Installing collected packages: tensorflow-gpu
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
import cv2
import imghdr

# %%
data_dir = 'data' 
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Loading data

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 156 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
data=data.map(lambda x,y: (x/255,y))

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1

# %%
train=data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # Modeling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

# %%
model=Sequential()
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 254, 254, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 14400)             0
#
#  dense_2 (Dense)             (None, 256)               3686656
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 3/3 [==============================] - 5s 1s/step - loss: 1.0064 - accuracy: 0.5417 - val_loss: 1.0918 - val_accuracy: 0.4333
# Epoch 2/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.7856 - accuracy: 0.4896 - val_loss: 0.6502 - val_accuracy: 0.5333
# Epoch 3/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.6544 - accuracy: 0.5521 - val_loss: 0.5977 - val_accuracy: 0.8667
# Epoch 4/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.5960 - accuracy: 0.7812 - val_loss: 0.5995 - val_accuracy: 0.6333
# Epoch 5/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.5980 - accuracy: 0.6354 - val_loss: 0.4872 - val_accuracy: 0.8500
# Epoch 6/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.4739 - accuracy: 0.7604 - val_loss: 0.4904 - val_accuracy: 0.7333
# Epoch 7/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.4463 - accuracy: 0.8438 - val_loss: 0.4105 - val_accuracy: 0.8833
# Epoch 8/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.3552 - accuracy: 0.8854 - val_loss: 0.3360 - val_accuracy: 0.8333
# Epoch 9/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.5090 - accuracy: 0.7604 - val_loss: 0.3376 - val_accuracy: 0.8333
# Epoch 10/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.4450 - accuracy: 0.7188 - val_loss: 0.2980 - val_accuracy: 0.9500
# Epoch 11/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.3505 - accuracy: 0.9062 - val_loss: 0.4051 - val_accuracy: 0.7667
# Epoch 12/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.4021 - accuracy: 0.7917 - val_loss: 0.2983 - val_accuracy: 0.9333
# Epoch 13/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.2381 - accuracy: 0.9479 - val_loss: 0.3104 - val_accuracy: 0.8500
# Epoch 14/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.2598 - accuracy: 0.9062 - val_loss: 0.1896 - val_accuracy: 0.9333
# Epoch 15/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.1558 - accuracy: 0.9583 - val_loss: 0.1188 - val_accuracy: 0.9833
# Epoch 16/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.1793 - accuracy: 0.9479 - val_loss: 0.0775 - val_accuracy: 0.9667
# Epoch 17/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.1152 - accuracy: 0.9688 - val_loss: 0.0599 - val_accuracy: 1.0000
# Epoch 18/20
# 3/3 [==============================] - 5s 1s/step - loss: 0.1609 - accuracy: 0.9062 - val_loss: 0.2289 - val_accuracy: 0.8667
# Epoch 19/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.1537 - accuracy: 0.9271 - val_loss: 0.0614 - val_accuracy: 1.0000
# Epoch 20/20
# 3/3 [==============================] - 6s 2s/step - loss: 0.0778 - accuracy: 0.9896 - val_loss: 0.0722 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
img = cv2.imread('happytest.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 74ms/step
# array([[0.0022507]], dtype=float32)

# %%
img = cv2.imread('sadtest.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
yhat2 = model.predict(np.expand_dims(resize/255, 0))
yhat2
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[0.869803]], dtype=float32)
